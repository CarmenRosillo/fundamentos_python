# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#leer

df_titanic= pd.read_csv("Titanic-Dataset.csv")

# %%
# df de los atributos flotantes del df original

df_plot= df_titanic[["Age", "Fare"]]
df_plot.plot()
# Out:
# <Axes: >

# %%
###grafica de uno de los atributos
df_plot= df_titanic[["Age"]]
df_plot.plot()
# Out:
# <Axes: >

# %%
###funcion scatter

# %%
df_titanic.plot.scatter ("Age", "Fare")
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>

# %%
### agregar categoria edad
### niño menor 12, adolescente 12-17 ,adulto 18-55, adulto mayor 56
print(df_titanic.columns.to_list())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
### atributosde interes

df_1= df_titanic[["Name", "Age" ]]

# %%
#df con edad valida
df_2= df_1[df_1["Age"].notna()]

# %%
df_2["category"]= df_2 ["Age"]
# Out:
# C:\Users\CarmenLu\AppData\Local\Temp\ipykernel_12668\63679464.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2["category"]= df_2 ["Age"]

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 714 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      714 non-null    object
#  1   Age       714 non-null    float64
#  2   category  714 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 22.3+ KB

# %% [markdown]
# apply aplicar funciones a un dataframe determinado
#
# Estadisticas basicas

# %%
df_titanic.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Describe Estadistica descriptiva

# %%
df_titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#descripcion de un par o mas atributos

colums_list= df_titanic.columns. to_list ()
print (colums_list)
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
colums_list_1= colums_list [5], colums_list [9]

# %% [markdown]
# agg metodo q recibe como argumento un diccionario, que lista

# %%
df_titanic.agg(
    {
        "Age": ["min", "max", "mean"],
        "Fare": ["min", "max", "mean"],
    }
)
# Out:
#             Age        Fare
# min    0.420000    0.000000
# max   80.000000  512.329200
# mean  29.699118   32.204208

# %%
#.groupby() para agrupar categorias y obtener descripciones de esas categorias

# %%
data = {
    "Category": ["A", "B", "A", "A", "B", "C", "C", "C"],
    "Values": [10, 20, 10, 30, 40, 50, 60, 70],
    "Quantity": [1, 2, 3, 4, 5, 6, 7, 8]
}

# %%
df_101= pd.DataFrame (data)
print (df_101)
# Out:
#   Category  Values  Quantity
# 0        A      10         1
# 1        B      20         2
# 2        A      10         3
# 3        A      30         4
# 4        B      40         5
# 5        C      50         6
# 6        C      60         7
# 7        C      70         8

# %%
#suma de los valores por categoria
df_101.groupby("Category")["Values"].sum()
# Out:
# Category
# A     50
# B     60
# C    180
# Name: Values, dtype: int64

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_102= df_titanic[[ "Sex", "Age"]].groupby("Sex").mean()

# %%
# promedio de la edad por sexo

print (df_102)
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
df_2.head()
# Out:
#                                                 Name   Age  category
# 0                            Braund, Mr. Owen Harris  22.0      22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      38.0
# 2                             Heikkinen, Miss. Laina  26.0      26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      35.0
# 4                           Allen, Mr. William Henry  35.0      35.0

# %%
df_2.head(20)
# Out:
#                                                  Name   Age  category
# 0                             Braund, Mr. Owen Harris  22.0      22.0
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      38.0
# 2                              Heikkinen, Miss. Laina  26.0      26.0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      35.0
# 4                            Allen, Mr. William Henry  35.0      35.0
# 6                             McCarthy, Mr. Timothy J  54.0      54.0
# 7                      Palsson, Master. Gosta Leonard   2.0       2.0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0      27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  14.0      14.0
# 10                    Sandstrom, Miss. Marguerite Rut   4.0       4.0
# 11                           Bonnell, Miss. Elizabeth  58.0      58.0
# 12                     Saundercock, Mr. William Henry  20.0      20.0
# ...
